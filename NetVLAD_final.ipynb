# %%
# %pwd
# Out:
# '/workspace/PyTorch/localdata/SuperGlue_final'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision

from torchvision.models import resnet18,vgg16

torch.manual_seed(777)

# %%
class AverageMeter(object):
    """
    Keeps track of most recent, average, sum, and count of a metric.
    """

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class NetVLAD(nn.Module):
    """NetVLAD layer implementation"""

    def __init__(self, num_clusters=12, dim=128, alpha=100.0,normalize_input=True):
        """
        Args:
            num_clusters : int
                The number of clusters
            dim : int
                Dimension of descriptors
            alpha : float
                Parameter of initialization. Larger value is harder assignment.
            normalize_input : bool
                If true, descriptor-wise L2 normalization is applied to input.
        """
        super(NetVLAD, self).__init__()
        self.num_clusters = num_clusters
        self.dim = dim
        self.alpha = alpha
        self.normalize_input = normalize_input
        self.conv = nn.Conv2d(dim, num_clusters, kernel_size=(1, 1), bias=False)
        self.centroids = nn.Parameter(torch.rand(num_clusters, dim))
        self._init_params()

    def _init_params(self):
        self.conv.weight = nn.Parameter(
            (2.0 * self.alpha * self.centroids).unsqueeze(-1).unsqueeze(-1)
        )

    def forward(self, x):

        N, C = x.shape[:2]

        if self.normalize_input:
            x = F.normalize(x, p=2, dim=1)  # across descriptor dim

        # soft-assignment
        soft_assign = self.conv(x).view(N, self.num_clusters, -1)
        soft_assign = F.softmax(soft_assign, dim=1)

        x_flatten = x.view(N, C, -1)
        
        # calculate residuals to each clusters
        vlad = torch.zeros([N, self.num_clusters, C], dtype=x.dtype, layout=x.layout, device=x.device)
        for C in range(self.num_clusters): # slower than non-looped, but lower memory usage 
            residual = x_flatten.unsqueeze(0).permute(1, 0, 2, 3) - \
                    self.centroids[C:C+1, :].expand(x_flatten.size(-1), -1, -1).permute(1, 2, 0).unsqueeze(0)
            residual *= soft_assign[:,C:C+1,:].unsqueeze(2)
            vlad[:,C:C+1,:] = residual.sum(dim=-1)

        vlad = F.normalize(vlad, p=2, dim=2)  # intra-normalization
        vlad = vlad.view(x.size(0), -1)  # flatten
        vlad = F.normalize(vlad, p=2, dim=1)  # L2 normalize

        return vlad

# %%
# VGG 16
encoder = vgg16(pretrained=True) # pretrained
layers = list(encoder.features.children())[:-2]

for l in layers[:-5]: 
    for p in l.parameters():
        p.requires_grad = False

model = nn.Module() 

encoder = nn.Sequential(*layers)
model.add_module('encoder', encoder)

dim = list(encoder.parameters())[-1].shape[0]  # last channels (512)

# Define model for embedding
net_vlad = NetVLAD(num_clusters=16, dim=dim)
model.add_module('pool', net_vlad)

model = model.cuda()

# %%
# Pretrained Model Load(Pittsburgh 30k)
# NetVLAD는 피츠버그 데이터셋을 이용해 학습하였음, 하지만 데이터셋의 용량이 크고 학습에 필요한 하드웨어 리소스 문제로 본 챌린지에서는 사전학습된 체크포인트를 제공함

load_model = torch.load('./pittsburgh_checkpoint.pth.tar')
model.load_state_dict(load_model['state_dict'],strict = False)
# Out:
# <All keys matched successfully>

# %%
import torch.utils.data as data
import torchvision.transforms as transforms

from random import choice
from os.path import join, exists
from collections import namedtuple
from scipy.io import loadmat
from PIL import Image
from sklearn.neighbors import NearestNeighbors
from IPython.display import display

class Dataset(data.Dataset) :
  
  def __init__(self,condition='train',
               ref_path = 'datasets/hyun_1st/ref',
               val_path = 'datasets/hyun_1st/val'
               q_path = 'datasets/hyun_1st/query', 
               thres = 2) :
    self.input_transform = transforms.Compose([
        transforms.Resize([640,480]),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                            std=[0.229, 0.224, 0.225]),
      ])
    
    self.condition = condition

    if self.condition == 'train' :
        self.images = list(glob.glob(ref_path+"/*.jpg"))
    elif self.condition == 'valid' :
        self.images = list(glob.glob(val_path+"/*.jpg"))
    else :
        self.images = list(glob.glob(q_path+"/*.jpg"))
    
    self.dbImage = list(glob.glob(ref_path+'/*.jpg'))
    self.valImage = list(glob.glob(val_path+'/*.jpg'))
    self.qImage = list(glob.glob(q_path+'/*.jpg'))
    
    self.locDb = []
    
    with open('odom_ref.pkl','rb') as f:
        for idx in sorted(glob.glob("datasets/hyun_1st/mapping/*.jpg")):
            idx = idx.split('mapping/')[1]
            self.locDb.append(idx)
    
    self.thres = thres
    
    self.positives = None
    self.distances = None

    self.getPositives()
  
  def __getitem__(self, index):

      if self.condition == 'train' :
        img = Image.open(self.images[index])
        img = self.input_transform(img)

        pos_list = self.positives[index].tolist()
        pos_list.remove(index)
        pos_index = self.positives[index][np.random.randint(0,len(self.positives[index]))]
        pos_img = Image.open(self.images[pos_index])
        pos_img = self.input_transform(pos_img)

        pos_list = pos_list + [index]
        neg_index = choice([i for i in range(len(self.images)) if i not in pos_list])
        neg_img = Image.open(self.images[neg_index])
        neg_img = self.input_transform(neg_img)
        
        img = torch.stack([img,pos_img,neg_img],dim=0)
        label = torch.Tensor([0, 0, 1])

        return img, label

      elif self.condition == 'test' :
        img = Image.open(self.images[index])
        img = self.input_transform(img)

        return img
      
      else :
        img = Image.open(self.images[index])
        img = self.input_transform(img)

        return img


  def __len__(self):
      return len(self.images)

  def getPositives(self):
      # positives for evaluation are those within trivial threshold range
      #fit NN to find them, search by radius
      if  self.condition == 'train' :
          knn = NearestNeighbors(n_jobs=1)
          knn.fit(self.dbStruct.locDb)

          self.distances, self.positives = knn.radius_neighbors(self.dbStruct.locDb,radius=self.dbStruct.posDistThr)
      else :
          knn = NearestNeighbors(n_jobs=1)
          knn.fit(self.dbStruct.locDb)

          self.distances, self.positives = knn.radius_neighbors(self.dbStruct.locQ,
                  radius=self.dbStruct.posDistThr)
            
      return self.positives

# %%
train_dataset = BerlinDataset(condition="train")
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1,shuffle=True,num_workers=0)

# %%
epochs = 5
global_batch_size = 4
lr = 0.00001
momentum = 0.9
weightDecay = 0.001
losses = AverageMeter()
best_loss = 100.0
margin = 0.1 

criterion = nn.TripletMarginLoss(margin=margin**0.5, p=2, reduction='sum').cuda()
optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=lr, momentum=momentum, weight_decay=weightDecay)

model.train()

count = 0

for epoch in range(epochs):
  for batch_idx, (train_image,train_label) in enumerate(train_loader) :
    output_train = model.encoder(train_image.squeeze().cuda()) # vgg16 통과
    output_train = model.pool(output_train) # netvlad 통과
    triplet_loss = criterion(output_train[0].reshape(1,-1),output_train[1].reshape(1,-1),output_train[2].reshape(1,-1))
        
    #이미지를 순서대로 뽑아 세개씩 연속적으로 비교
    #writer.add_scalar('Loss/train', losses.avg, batch_idx)

    if batch_idx == 0 :
      optimizer.zero_grad() # gradient 초기화

    triplet_loss.backward(retain_graph=True) # 역전파
    losses.update(triplet_loss.item()) # loss 업데이트
    
    if (batch_idx +1) % global_batch_size == 0 :# 모르겟
      for name, p in model.named_parameters():
        if p.requires_grad:
          p.grad /= global_batch_size
    
        optimizer.step()
        optimizer.zero_grad()

    if batch_idx % 20 == 0 and batch_idx != 0:
        print('epoch : {}, batch_idx  : {}, triplet_loss : {}'.format(epoch,batch_idx,losses.avg))
    
    
    if best_loss > losses.avg : # 최적의 model 발견시 best_model 업데이트
        best_save_name = 'best_model.pt'
        best_path = F"./ckpt/{best_save_name}" 
        torch.save(model.state_dict(), best_path)
        count = 0
    else:
        count += 1
        if count >= 1000 :
            break
            
  model_save_name = 'model_{:02d}.pt'.format(epoch) # epoch마다 model 저장
  path = F"./ckpt/{model_save_name}" 
  torch.save(model.state_dict(), path)
#writer.close()
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448224956/work/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# epoch : 0, batch_idx  : 20, triplet_loss : 0.20565155290421985
# epoch : 0, batch_idx  : 40, triplet_loss : 0.23252017614318105
# epoch : 0, batch_idx  : 60, triplet_loss : 0.21935416538207259
# epoch : 0, batch_idx  : 80, triplet_loss : 0.21188656562640343
# epoch : 0, batch_idx  : 100, triplet_loss : 0.2129280183574941
# epoch : 0, batch_idx  : 120, triplet_loss : 0.2139482123792664
# epoch : 0, batch_idx  : 140, triplet_loss : 0.22249459078971376
# epoch : 0, batch_idx  : 160, triplet_loss : 0.22114218021771923
# epoch : 0, batch_idx  : 180, triplet_loss : 0.22525180999745323
# epoch : 0, batch_idx  : 200, triplet_loss : 0.2200638325653266
# epoch : 0, batch_idx  : 220, triplet_loss : 0.22255538006174078
# epoch : 0, batch_idx  : 240, triplet_loss : 0.22237187252994395
# epoch : 0, batch_idx  : 260, triplet_loss : 0.2176955554677152
# epoch : 0, batch_idx  : 280, triplet_loss : 0.21772530346154317
# epoch : 0, batch_idx  : 300, triplet_loss : 0.21834557060387444
# epoch : 0, batch_idx  : 320, triplet_loss : 0.21964800320681754
# epoch : 0, batch_idx  : 340, triplet_loss : 0.22176833900887946
# epoch : 0, batch_idx  : 360, triplet_loss : 0.2227540234119278
# epoch : 0, batch_idx  : 380, triplet_loss : 0.22277435339654839
# epoch : 0, batch_idx  : 400, triplet_loss : 0.221688586726153
# epoch : 0, batch_idx  : 420, triplet_loss : 0.22403294782457328
# epoch : 0, batch_idx  : 440, triplet_loss : 0.22364297299698638
# epoch : 0, batch_idx  : 460, triplet_loss : 0.22358135921060393
# epoch : 0, batch_idx  : 480, triplet_loss : 0.22224237913897033
# epoch : 0, batch_idx  : 500, triplet_loss : 0.2229444447629704
# epoch : 0, batch_idx  : 520, triplet_loss : 0.22108287911955088
# epoch : 0, batch_idx  : 540, triplet_loss : 0.22283202398726767
# epoch : 0, batch_idx  : 560, triplet_loss : 0.2214798669126582
# epoch : 0, batch_idx  : 580, triplet_loss : 0.22124771232654222
# epoch : 0, batch_idx  : 600, triplet_loss : 0.2220115768730938
# epoch : 0, batch_idx  : 620, triplet_loss : 0.22243068701979044
# epoch : 0, batch_idx  : 640, triplet_loss : 0.22163059447373318
# epoch : 0, batch_idx  : 660, triplet_loss : 0.21976933059100845
# epoch : 0, batch_idx  : 680, triplet_loss : 0.21767341311632624
# epoch : 0, batch_idx  : 700, triplet_loss : 0.21702150534971296
# epoch : 0, batch_idx  : 720, triplet_loss : 0.2173754157867908
# epoch : 0, batch_idx  : 740, triplet_loss : 0.21680689622194338
# epoch : 0, batch_idx  : 760, triplet_loss : 0.21802985957981566
# epoch : 0, batch_idx  : 780, triplet_loss : 0.21788289314958717
# epoch : 0, batch_idx  : 800, triplet_loss : 0.2173926867498143
# epoch : 0, batch_idx  : 820, triplet_loss : 0.21695333603093453
# epoch : 0, batch_idx  : 840, triplet_loss : 0.2154530604302387
# epoch : 0, batch_idx  : 860, triplet_loss : 0.2151021109363897
# epoch : 0, batch_idx  : 880, triplet_loss : 0.21404987600685926
# epoch : 0, batch_idx  : 900, triplet_loss : 0.21468573888054698
# epoch : 0, batch_idx  : 920, triplet_loss : 0.2139281635046264
# epoch : 0, batch_idx  : 940, triplet_loss : 0.21356664213186624
# epoch : 0, batch_idx  : 960, triplet_loss : 0.21433490657409446
# epoch : 0, batch_idx  : 980, triplet_loss : 0.21479870413907565
# epoch : 0, batch_idx  : 1000, triplet_loss : 0.2148249289253494
# epoch : 0, batch_idx  : 1020, triplet_loss : 0.21512103197506896
# epoch : 0, batch_idx  : 1040, triplet_loss : 0.21598719187818044
# epoch : 0, batch_idx  : 1060, triplet_loss : 0.2160486877245458
# epoch : 0, batch_idx  : 1080, triplet_loss : 0.21513038079679067
# epoch : 0, batch_idx  : 1100, triplet_loss : 0.21474522763658502
# epoch : 0, batch_idx  : 1120, triplet_loss : 0.2148819915637919
# epoch : 0, batch_idx  : 1140, triplet_loss : 0.21599039291729538
# epoch : 0, batch_idx  : 1160, triplet_loss : 0.2166726424404509
# epoch : 0, batch_idx  : 1180, triplet_loss : 0.2164550260100498
# epoch : 0, batch_idx  : 1200, triplet_loss : 0.21562685929766107
# epoch : 0, batch_idx  : 1220, triplet_loss : 0.21603172060703274
# epoch : 0, batch_idx  : 1240, triplet_loss : 0.21551375567768966
# epoch : 0, batch_idx  : 1260, triplet_loss : 0.21550402189416606
# epoch : 0, batch_idx  : 1280, triplet_loss : 0.2160574386680061
# epoch : 0, batch_idx  : 1300, triplet_loss : 0.21609807060279818
# epoch : 0, batch_idx  : 1320, triplet_loss : 0.21599403238043832
# epoch : 0, batch_idx  : 1340, triplet_loss : 0.2157817025579329
# epoch : 0, batch_idx  : 1360, triplet_loss : 0.21506385357392177
# epoch : 0, batch_idx  : 1380, triplet_loss : 0.2150900511531015
# epoch : 0, batch_idx  : 1400, triplet_loss : 0.21564223368962607
# epoch : 0, batch_idx  : 1420, triplet_loss : 0.21564446550116917
# epoch : 0, batch_idx  : 1440, triplet_loss : 0.2157913774438073
# epoch : 0, batch_idx  : 2300, triplet_loss : 0.21365569993652814
# epoch : 0, batch_idx  : 2320, triplet_loss : 0.2136342492867831
# epoch : 0, batch_idx  : 2340, triplet_loss : 0.21303489843732726
# epoch : 0, batch_idx  : 2360, triplet_loss : 0.21328804943330304
# epoch : 0, batch_idx  : 2380, triplet_loss : 0.2134882849036821
# epoch : 0, batch_idx  : 2400, triplet_loss : 0.21316892623603467
# epoch : 0, batch_idx  : 2420, triplet_loss : 0.21328940671221966
# epoch : 0, batch_idx  : 2440, triplet_loss : 0.21337573980513483
# epoch : 0, batch_idx  : 2460, triplet_loss : 0.21347718595344328
# epoch : 0, batch_idx  : 2480, triplet_loss : 0.21342052835843486
# epoch : 0, batch_idx  : 2500, triplet_loss : 0.2129880470640418
# epoch : 0, batch_idx  : 2520, triplet_loss : 0.21301204285324685
# epoch : 0, batch_idx  : 2540, triplet_loss : 0.21291466295977177
# epoch : 0, batch_idx  : 2560, triplet_loss : 0.21271597398812303
# epoch : 0, batch_idx  : 2580, triplet_loss : 0.21262328006278078
# epoch : 0, batch_idx  : 2600, triplet_loss : 0.21201402684534024
# epoch : 0, batch_idx  : 2620, triplet_loss : 0.21209422091589952
# epoch : 0, batch_idx  : 2640, triplet_loss : 0.21188192850981008
# epoch : 0, batch_idx  : 2660, triplet_loss : 0.21182862052967655
# epoch : 0, batch_idx  : 2680, triplet_loss : 0.2122170267288296
# epoch : 0, batch_idx  : 2700, triplet_loss : 0.21179188109909505
# epoch : 0, batch_idx  : 2720, triplet_loss : 0.21188784215170775
# epoch : 0, batch_idx  : 2740, triplet_loss : 0.21221762436752292
# epoch : 0, batch_idx  : 2760, triplet_loss : 0.21224267883863798
# epoch : 0, batch_idx  : 2780, triplet_loss : 0.2120285550281754
# epoch : 0, batch_idx  : 2800, triplet_loss : 0.21213225795302548
# epoch : 0, batch_idx  : 2820, triplet_loss : 0.21220494542126958
# epoch : 0, batch_idx  : 2840, triplet_loss : 0.21202312855181749
# epoch : 0, batch_idx  : 2860, triplet_loss : 0.21189958765472577
# epoch : 0, batch_idx  : 2880, triplet_loss : 0.211950088801048
# epoch : 0, batch_idx  : 2900, triplet_loss : 0.21218632844266133
# epoch : 0, batch_idx  : 2920, triplet_loss : 0.21164466903373746
# epoch : 0, batch_idx  : 2940, triplet_loss : 0.21198798342652567
# epoch : 0, batch_idx  : 2960, triplet_loss : 0.21192212768681587
# epoch : 0, batch_idx  : 2980, triplet_loss : 0.21200769515854925
# epoch : 0, batch_idx  : 3000, triplet_loss : 0.21223550842269903
# epoch : 0, batch_idx  : 3020, triplet_loss : 0.21221062993813886
# epoch : 0, batch_idx  : 3040, triplet_loss : 0.212374922457748
# epoch : 0, batch_idx  : 3060, triplet_loss : 0.21237964012466276
# epoch : 0, batch_idx  : 3080, triplet_loss : 0.21237403411673322
# epoch : 0, batch_idx  : 3100, triplet_loss : 0.21224138197380663
# epoch : 0, batch_idx  : 3120, triplet_loss : 0.21232920984395304
# epoch : 0, batch_idx  : 3140, triplet_loss : 0.2123828483250292
# epoch : 0, batch_idx  : 3160, triplet_loss : 0.21285732831052873
# epoch : 0, batch_idx  : 3180, triplet_loss : 0.21297265438867116
# epoch : 0, batch_idx  : 3200, triplet_loss : 0.21318569113708444
# epoch : 0, batch_idx  : 3220, triplet_loss : 0.21345192053346893
# epoch : 0, batch_idx  : 3240, triplet_loss : 0.21312474593892577
# epoch : 0, batch_idx  : 3260, triplet_loss : 0.21313618337841203
# epoch : 0, batch_idx  : 3280, triplet_loss : 0.21346832004780814
# epoch : 0, batch_idx  : 3300, triplet_loss : 0.2132295289208621
# epoch : 0, batch_idx  : 3320, triplet_loss : 0.21300630733141945
# epoch : 0, batch_idx  : 3340, triplet_loss : 0.21265605679888527
# epoch : 0, batch_idx  : 3360, triplet_loss : 0.2128554001091421
# epoch : 0, batch_idx  : 3380, triplet_loss : 0.21297771835143803
# epoch : 0, batch_idx  : 3400, triplet_loss : 0.21277795364421384
# epoch : 0, batch_idx  : 3420, triplet_loss : 0.21266667512173335
# epoch : 0, batch_idx  : 3440, triplet_loss : 0.2126427290571945
# epoch : 0, batch_idx  : 3460, triplet_loss : 0.21246198101286184
# epoch : 0, batch_idx  : 3480, triplet_loss : 0.21228836496066034
# epoch : 0, batch_idx  : 3500, triplet_loss : 0.21205455968802875
# epoch : 0, batch_idx  : 3520, triplet_loss : 0.21217951763424472
# epoch : 0, batch_idx  : 3540, triplet_loss : 0.2122495343240093
# epoch : 0, batch_idx  : 3560, triplet_loss : 0.21221011048520225
# epoch : 0, batch_idx  : 3580, triplet_loss : 0.21218761221652122
# epoch : 0, batch_idx  : 3600, triplet_loss : 0.21217123427943235
# epoch : 0, batch_idx  : 3620, triplet_loss : 0.21201648843186366
# epoch : 0, batch_idx  : 3640, triplet_loss : 0.2122717596645769
# epoch : 0, batch_idx  : 3660, triplet_loss : 0.21200797128664342
# epoch : 0, batch_idx  : 3680, triplet_loss : 0.21177738725216094
# epoch : 0, batch_idx  : 3700, triplet_loss : 0.21212033847318215
# epoch : 0, batch_idx  : 3720, triplet_loss : 0.21201657406331006
# epoch : 0, batch_idx  : 3740, triplet_loss : 0.2121429198631403
# epoch : 0, batch_idx  : 3760, triplet_loss : 0.21216548143692138
# epoch : 0, batch_idx  : 3780, triplet_loss : 0.21202735311611087
# epoch : 0, batch_idx  : 3800, triplet_loss : 0.21170510346561444
# epoch : 0, batch_idx  : 3820, triplet_loss : 0.21163158373382196
# epoch : 0, batch_idx  : 3840, triplet_loss : 0.21148593014213327
# epoch : 0, batch_idx  : 3860, triplet_loss : 0.21134907206362685
# epoch : 0, batch_idx  : 3880, triplet_loss : 0.21109492399126745
# epoch : 0, batch_idx  : 3900, triplet_loss : 0.21125857801322478
# epoch : 0, batch_idx  : 3920, triplet_loss : 0.21114229859517747
# epoch : 0, batch_idx  : 3940, triplet_loss : 0.21099708799298297
# epoch : 0, batch_idx  : 3960, triplet_loss : 0.21101110278281018
# epoch : 0, batch_idx  : 4840, triplet_loss : 0.21134140615348998
# epoch : 0, batch_idx  : 4860, triplet_loss : 0.21150551416628205
# epoch : 0, batch_idx  : 4880, triplet_loss : 0.21178933440161346
# epoch : 0, batch_idx  : 4900, triplet_loss : 0.21151044714866768
# epoch : 0, batch_idx  : 4920, triplet_loss : 0.21164440384387873
# epoch : 0, batch_idx  : 4940, triplet_loss : 0.21146750288486385
# epoch : 0, batch_idx  : 4960, triplet_loss : 0.21130260526593284
# epoch : 0, batch_idx  : 4980, triplet_loss : 0.2110991835402715
# epoch : 0, batch_idx  : 5000, triplet_loss : 0.2110881244056441
# epoch : 0, batch_idx  : 5020, triplet_loss : 0.2111003834800971
# epoch : 0, batch_idx  : 5040, triplet_loss : 0.2111382017389126
# epoch : 0, batch_idx  : 5060, triplet_loss : 0.21124982829151406
# epoch : 0, batch_idx  : 5080, triplet_loss : 0.21125258465166097
# epoch : 0, batch_idx  : 5100, triplet_loss : 0.21119022950124003
# epoch : 0, batch_idx  : 5120, triplet_loss : 0.21132962997246943
# epoch : 0, batch_idx  : 5140, triplet_loss : 0.21133372915136608
# epoch : 0, batch_idx  : 5160, triplet_loss : 0.2115132184228193
# epoch : 0, batch_idx  : 5180, triplet_loss : 0.21153898745102212
# epoch : 0, batch_idx  : 5200, triplet_loss : 0.2113464739867711
# epoch : 0, batch_idx  : 5220, triplet_loss : 0.2112778112751797
# epoch : 0, batch_idx  : 5240, triplet_loss : 0.2111746974174268
# epoch : 0, batch_idx  : 5260, triplet_loss : 0.21121810085758513
# epoch : 0, batch_idx  : 5280, triplet_loss : 0.21121118319709517
# epoch : 0, batch_idx  : 5300, triplet_loss : 0.2115814709209132
# epoch : 0, batch_idx  : 5320, triplet_loss : 0.21162773144242908
# epoch : 0, batch_idx  : 5340, triplet_loss : 0.21155996271073427
# epoch : 0, batch_idx  : 5360, triplet_loss : 0.21160019681516412
# epoch : 0, batch_idx  : 5380, triplet_loss : 0.21147474335862057
# epoch : 0, batch_idx  : 5400, triplet_loss : 0.2113031090861933
# epoch : 0, batch_idx  : 5420, triplet_loss : 0.2112999074112949
# epoch : 0, batch_idx  : 5440, triplet_loss : 0.21123244210959927
# epoch : 0, batch_idx  : 5460, triplet_loss : 0.211239369988245
# epoch : 0, batch_idx  : 5480, triplet_loss : 0.21138058334474819
# epoch : 0, batch_idx  : 5500, triplet_loss : 0.21154989756967474
# epoch : 0, batch_idx  : 5520, triplet_loss : 0.21162328041457024
# epoch : 0, batch_idx  : 5540, triplet_loss : 0.21156360580912137
# epoch : 0, batch_idx  : 5560, triplet_loss : 0.21153463365105155
# epoch : 0, batch_idx  : 5580, triplet_loss : 0.21156198171876361
# epoch : 0, batch_idx  : 5600, triplet_loss : 0.21139606171006753
# epoch : 0, batch_idx  : 5620, triplet_loss : 0.21156162290763142
# epoch : 0, batch_idx  : 5640, triplet_loss : 0.21160093849589903
# epoch : 0, batch_idx  : 5660, triplet_loss : 0.21164514425259515
# epoch : 0, batch_idx  : 5680, triplet_loss : 0.21169379283751932
# epoch : 0, batch_idx  : 5700, triplet_loss : 0.21163732117674808
# epoch : 0, batch_idx  : 5720, triplet_loss : 0.21159446475972998
# epoch : 0, batch_idx  : 5740, triplet_loss : 0.21176097677925534
# epoch : 0, batch_idx  : 5760, triplet_loss : 0.21155281063583736
# epoch : 0, batch_idx  : 5780, triplet_loss : 0.21163418476112655
# epoch : 0, batch_idx  : 5800, triplet_loss : 0.2115639135911945
# epoch : 0, batch_idx  : 5820, triplet_loss : 0.21171912716295563
# epoch : 0, batch_idx  : 5840, triplet_loss : 0.21172929932617648
# epoch : 0, batch_idx  : 5860, triplet_loss : 0.2118977193660733
# epoch : 0, batch_idx  : 5880, triplet_loss : 0.21197731955848853
# epoch : 0, batch_idx  : 5900, triplet_loss : 0.21194913515174335
# epoch : 0, batch_idx  : 5920, triplet_loss : 0.21184277619044736
# epoch : 0, batch_idx  : 5940, triplet_loss : 0.21167118459854678
# epoch : 0, batch_idx  : 5960, triplet_loss : 0.21155211737923446
# epoch : 0, batch_idx  : 5980, triplet_loss : 0.21151401718171858
# epoch : 0, batch_idx  : 6000, triplet_loss : 0.21143969353626738
# epoch : 0, batch_idx  : 6020, triplet_loss : 0.21130017601875467
# epoch : 0, batch_idx  : 6040, triplet_loss : 0.2111770524486882
# epoch : 0, batch_idx  : 6060, triplet_loss : 0.21114107649272434
# epoch : 0, batch_idx  : 6080, triplet_loss : 0.21113694876633354
# epoch : 0, batch_idx  : 6100, triplet_loss : 0.21110393713388534
# epoch : 0, batch_idx  : 6120, triplet_loss : 0.21106896927652358
# epoch : 0, batch_idx  : 6140, triplet_loss : 0.2108707632678395
# epoch : 0, batch_idx  : 6160, triplet_loss : 0.21085743660509654
# epoch : 0, batch_idx  : 6180, triplet_loss : 0.2109058579374837
# epoch : 0, batch_idx  : 6200, triplet_loss : 0.21091359349109148
# epoch : 0, batch_idx  : 6220, triplet_loss : 0.21061657753582458
# epoch : 0, batch_idx  : 6240, triplet_loss : 0.21059864032652453
# epoch : 0, batch_idx  : 6260, triplet_loss : 0.21063183726184456
# epoch : 0, batch_idx  : 6280, triplet_loss : 0.21077607943362214
# epoch : 0, batch_idx  : 6300, triplet_loss : 0.21073824464281557
# epoch : 0, batch_idx  : 6320, triplet_loss : 0.21090140011355463
# epoch : 0, batch_idx  : 6340, triplet_loss : 0.21088275705822407
# epoch : 0, batch_idx  : 6360, triplet_loss : 0.21105836864313116
# epoch : 0, batch_idx  : 6380, triplet_loss : 0.21113487882424328
# epoch : 0, batch_idx  : 6400, triplet_loss : 0.2110489541488669
# epoch : 0, batch_idx  : 6420, triplet_loss : 0.2109862949929492
# epoch : 0, batch_idx  : 6440, triplet_loss : 0.21100334356038805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_143/3613891918.py in <module>
#      31       optimizer.zero_grad() # gradient 초기화
#      32
# ---> 33     triplet_loss.backward(retain_graph=True) # 역전파
#      34     losses.update(triplet_loss.item()) # loss 업데이트
#      35
#
# /opt/conda/lib/python3.7/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /opt/conda/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:
